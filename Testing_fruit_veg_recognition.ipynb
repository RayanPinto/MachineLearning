# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt

# %% [markdown]
# Dataset Link: https://www.kaggle.com/datasets/kritikseth/fruit-and-vegetable-image-recognition

# %% [markdown]
# # Test set Image Processing

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    'test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# # Loading Model

# %%
cnn = tf.keras.models.load_model('trained_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# #Visualising and Performing Prediction on Single image

# %%
#Test Image Visualization
import cv2
image_path = r"C:\Users\Rayan\Downloads\charming-photo-ripe-banana-lying-260nw-2475573467.webp"
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# #Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step

# %%
print(predictions)
# Out:
# [[2.9892063e-01 2.4459159e-03 2.0867822e-06 1.3873691e-03 4.2938072e-07
#   8.3029196e-02 3.1251234e-06 6.5031601e-03 1.7542207e-03 7.9288691e-02
#   1.3976656e-04 6.0000423e-07 1.5249997e-04 1.2533041e-04 1.7244727e-05
#   5.7707675e-05 9.3820026e-06 1.2417973e-01 3.7946268e-07 3.3561164e-01
#   1.9625775e-04 5.0066565e-03 5.5129624e-07 1.4997381e-04 1.4596762e-06
#   1.4816267e-06 7.9439297e-07 1.7863685e-04 4.6943716e-04 2.6175076e-05
#   5.4827592e-06 6.0282048e-02 4.1337662e-05 9.4797633e-07 5.5383334e-06
#   4.2360489e-06]]

# %%
# test_set.class_names

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 19

# %%
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a mango
